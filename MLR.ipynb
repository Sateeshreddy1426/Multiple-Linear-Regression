# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df=pd.read_csv("ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.dtypes
# Out:
# Price         int64
# Age_08_04     int64
# KM            int64
# Fuel_Type    object
# HP            int64
# Automatic     int64
# cc            int64
# Doors         int64
# Cylinders     int64
# Gears         int64
# Weight        int64
# dtype: object

# %%
df.isnull().sum()         # There are Null Values in the dataset
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(keep='first',ignore_index=True,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1430   7500         69  20544    Petrol   86          0  1300      3
# 1431  10845         72  19000    Petrol   86          0  1300      3
# 1432   8500         71  17016    Petrol   86          0  1300      3
# 1433   7250         70  16916    Petrol   86          0  1300      3
# 1434   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1435.000000  1435.000000    1435.000000  1435.000000  1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986     0.055749
# std     3608.732978    18.563312   37491.094553    14.981408     0.229517
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000     0.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                  cc        Doors  Cylinders        Gears       Weight
# count   1435.000000  1435.000000     1435.0  1435.000000  1435.000000
# mean    1576.560976     4.032753        4.0     5.026481  1072.287108
# std      424.387533     0.952667        0.0     0.188575    52.251882
# ...

# %%
df.dtypes
# Out:
# Price         int64
# Age_08_04     int64
# KM            int64
# Fuel_Type    object
# HP            int64
# Automatic     int64
# cc            int64
# Doors         int64
# Cylinders     int64
# Gears         int64
# Weight        int64
# dtype: object

# %%
# Converting Fuel Column to Numerical Variables

# %%
df=pd.get_dummies(df,dtype='int')
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1430   7500         69  20544   86          0  1300      3          4      5
# 1431  10845         72  19000   86          0  1300      3          4      5
# 1432   8500         71  17016   86          0  1300      3          4      5
# 1433   7250         70  16916   86          0  1300      3          4      5
# 1434   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# There are outliers in the dataset. Since we need to remove them.

# %%
Q3=df.quantile(0.75)
Q1=df.quantile(0.25)
Q1,Q3
# Out:
# (Price                8450.0
#  Age_08_04              44.0
#  KM                  43000.0
#  HP                     90.0
#  Automatic               0.0
#  cc                   1400.0
#  Doors                   3.0
#  Cylinders               4.0
#  Gears                   5.0
#  Weight               1040.0
#  Fuel_Type_CNG           0.0
#  Fuel_Type_Diesel        0.0
#  Fuel_Type_Petrol        1.0
#  Name: 0.25, dtype: float64,
#  Price               11950.0
#  Age_08_04              70.0
#  KM                  87041.5
#  HP                    110.0
#  Automatic               0.0
#  cc                   1600.0
#  Doors                   5.0
#  Cylinders               4.0
#  Gears                   5.0
#  Weight               1085.0
#  Fuel_Type_CNG           0.0
#  Fuel_Type_Diesel        0.0
#  Fuel_Type_Petrol        1.0
#  Name: 0.75, dtype: float64)

# %%
IQR=Q3-Q1
IQR
# Out:
# Price                3500.0
# Age_08_04              26.0
# KM                  44041.5
# HP                     20.0
# Automatic               0.0
# cc                    200.0
# Doors                   2.0
# Cylinders               0.0
# Gears                   0.0
# Weight                 45.0
# Fuel_Type_CNG           0.0
# Fuel_Type_Diesel        0.0
# Fuel_Type_Petrol        0.0
# dtype: float64

# %%
l_e=Q1-1.5*IQR
u_e=Q3+1.5*IQR
l_e,u_e
# Out:
# (Price                3200.00
#  Age_08_04               5.00
#  KM                 -23062.25
#  HP                     60.00
#  Automatic               0.00
#  cc                   1100.00
#  Doors                   0.00
#  Cylinders               4.00
#  Gears                   5.00
#  Weight                972.50
#  Fuel_Type_CNG           0.00
#  Fuel_Type_Diesel        0.00
#  Fuel_Type_Petrol        1.00
#  dtype: float64,
#  Price                17200.00
#  Age_08_04              109.00
#  KM                  153103.75
#  HP                     140.00
#  Automatic                0.00
#  cc                    1900.00
#  Doors                    8.00
#  Cylinders                4.00
#  Gears                    5.00
#  Weight                1152.50
#  Fuel_Type_CNG            0.00
#  Fuel_Type_Diesel         0.00
#  Fuel_Type_Petrol         1.00
#  dtype: float64)

# %%
df1=df[((df>=l_e) & (df<=u_e)).all(axis=1)]
df1
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 18    16750         24  25563  110          0  1600      3          4      5
# 19    16950         30  64359  110          0  1600      3          4      5
# 20    15950         30  67660  110          0  1600      3          4      5
# 22    15950         28  56349  110          0  1600      3          4      5
# 23    16950         28  32220  110          0  1600      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1430   7500         69  20544   86          0  1300      3          4      5
# 1431  10845         72  19000   86          0  1300      3          4      5
# 1432   8500         71  17016   86          0  1300      3          4      5
# 1433   7250         70  16916   86          0  1300      3          4      5
# 1434   6950         76      1  110          0  1600      5          4      5
#
# ...

# %%
sns.boxplot(data=df1)              # After removing the Extreme Outliers
# Out:
# <Axes: >

# %%
df1.isnull().sum()
# Out:
# Price               0
# Age_08_04           0
# KM                  0
# HP                  0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Weight              0
# Fuel_Type_CNG       0
# Fuel_Type_Diesel    0
# Fuel_Type_Petrol    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Split the dataset into training and testing sets (e.g., 80% training, 20% testing).

# %%
from sklearn.model_selection import train_test_split

# %%
features=df1.drop(columns='Price')
Target=df1['Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(features,Target,train_size=0.8,random_state=45)

# %%
x_train
# Out:
#       Age_08_04      KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 1192         70   89983  110          0  1600      3          4      5
# 641          68  119289  110          0  1600      4          4      5
# 1408         75   43720  110          0  1600      5          4      5
# 1350         70   60600   86          0  1300      3          4      5
# 322          44   36066  110          0  1600      3          4      5
# ...         ...     ...  ...        ...   ...    ...        ...    ...
# 852          68   65000  110          0  1600      5          4      5
# 314          41   37533  110          0  1600      5          4      5
# 884          62   61254  110          0  1600      5          4      5
# 647          64  116000   86          0  1300      5          4      5
# 1334         80   64000  110          0  1600      3          4      5
#
#       Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
x_test
# Out:
#       Age_08_04      KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 1189         77   90305   86          0  1300      3          4      5
# 1156         69   99374   86          0  1300      5          4      5
# 732          68   84976  110          0  1600      4          4      5
# 722          61   88127   86          0  1300      3          4      5
# 846          67   65785  110          0  1600      5          4      5
# ...         ...     ...  ...        ...   ...    ...        ...    ...
# 23           28   32220  110          0  1600      3          4      5
# 676          63  102807   86          0  1300      5          4      5
# 1335         79   63918  110          0  1600      4          4      5
# 1349         76   60833  110          0  1600      4          4      5
# 1234         71   82700  110          0  1600      3          4      5
#
#       Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
y_train
# Out:
# 1192     8450
# 641      7950
# 1408     7900
# 1350     5845
# 322     11250
#         ...
# 852      9000
# 314     13950
# 884      9950
# 647      8000
# 1334     8950
# Name: Price, Length: 847, dtype: int64

# %%
y_test
# Out:
# 1189     6950
# 1156     8950
# 732      9250
# 722      7950
# 846     10950
#         ...
# 23      16950
# 676      9250
# 1335     8500
# 1349     7750
# 1234     7950
# Name: Price, Length: 212, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
mul_model=LinearRegression()
mul_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# 1. Building With All Features

# %%
# Training Validation

# %%
y_pred_train=mul_model.predict(x_train)
y_pred_train
# Out:
# array([ 8540.46855289,  7824.24621199,  8910.6593825 ,  9288.01503867,
#        11762.74814975,  8586.33776722,  9241.84455509,  8879.17319108,
#         7426.30441641, 11825.23235229,  8083.88867869,  8552.56663263,
#        10050.76182241,  9565.64009998, 12663.18535009,  7747.40224675,
#         9152.10042327, 14797.48400854, 11511.6486951 , 10509.71036187,
#        15257.04624599, 11730.60720327,  9022.48985484, 10895.00296098,
#         7743.57909326, 15169.8103443 , 11385.65230691, 10973.90340352,
#        11867.70487303, 15139.10728747, 11272.42850001,  7975.78354981,
#         8714.20664901,  7766.0587248 , 13265.74782936, 12893.94299506,
#        13238.59228456, 11947.10640901,  8435.40413485,  8499.23090859,
#         8757.33791053,  7889.17228152,  8059.88616578,  7920.33457217,
#         9512.86509377, 13282.47677743,  7632.14073913,  7110.43642444,
#         9275.94393264, 12389.20097513, 13322.57050137,  8089.00757255,
# ...

# %%
from sklearn.metrics import r2_score , mean_squared_error

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.8302900128759187

# %%
mean_squared_error(y_train,y_pred_train)
# Out:
# 936985.1682054693

# %%
# coefficients
mul_model.coef_
# Out:
# array([-1.06780498e+02, -1.46352722e-02, -7.65772484e+01,  6.11066753e-13,
#         5.53179621e+00,  0.00000000e+00,  0.00000000e+00,  2.08958961e+01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00])

# %%
mul_model.intercept_
# Out:
# -5197.250536770129

# %%
# There is 83% Accuracy by predicting thr training Validation

# %%
# Testing Validation

# %%
y_predict_test=mul_model.predict(x_test)
y_predict_test
# Out:
# array([ 7105.2201374 ,  8160.87735872,  8326.39777963,  8840.20589139,
#         9550.74723493, 11367.26341002,  6682.85157628,  9644.58148721,
#         9429.67118049, 10477.56820081, 12674.37650218,  8269.19966007,
#        12618.28090833, 15341.94063715, 11167.71429784,  8871.31158735,
#        10907.72957783, 11155.75518128, 10906.90320818,  9405.14319309,
#         9333.14527056, 12301.26986725, 11673.56036799,  9795.1645576 ,
#         9390.39525035,  6858.16771785, 11564.50231797, 10623.16707134,
#        11272.92393697, 10529.9701513 ,  8504.09312478,  9184.15049675,
#        10136.42716391,  7756.02306284,  8203.0052226 ,  9353.50712439,
#         9956.05984604,  9771.9514728 , 12474.91066516,  8384.80847681,
#        15671.68124165,  7963.5254509 , 10810.70839371,  8712.12772671,
#        11132.33719323,  9096.11655828,  9153.25229796,  8953.61101752,
#         7794.46309496, 12649.41530187,  9110.63532284, 11105.61337084,
# ...

# %%
r2_score(y_test,y_predict_test)
# Out:
# 0.8178599254583384

# %%
mean_squared_error(y_test,y_predict_test)
# Out:
# 958691.1904428393

# %%
# There is 81% Accuracy in Testing Validation

# %%
df1.head(10)
# Out:
#     Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 18  16750         24  25563  110          0  1600      3          4      5
# 19  16950         30  64359  110          0  1600      3          4      5
# 20  15950         30  67660  110          0  1600      3          4      5
# 22  15950         28  56349  110          0  1600      3          4      5
# 23  16950         28  32220  110          0  1600      3          4      5
# 24  16250         29  25813  110          0  1600      3          4      5
# 25  15950         25  28450  110          0  1600      3          4      5
# 27  15750         29  41415  110          0  1600      3          4      5
# 28  16950         28  44142  110          0  1600      3          4      5
# 30  12950         29   9750   97          0  1400      3          4      5
#
#     Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 18    1065              0                 0                 1
# ...

# %%
df1.corr()
# Out:
#                      Price  Age_08_04        KM        HP  Automatic  \
# Price             1.000000  -0.878494 -0.552017  0.150046        NaN
# Age_08_04        -0.878494   1.000000  0.521188 -0.060962        NaN
# KM               -0.552017   0.521188  1.000000  0.032014        NaN
# HP                0.150046  -0.060962  0.032014  1.000000        NaN
# Automatic              NaN        NaN       NaN       NaN        NaN
# cc                0.102613  -0.005684  0.065521  0.994182        NaN
# Doors             0.190464  -0.101982 -0.014346  0.223103        NaN
# Cylinders              NaN        NaN       NaN       NaN        NaN
# Gears                  NaN        NaN       NaN       NaN        NaN
# Weight            0.513079  -0.373876 -0.143416  0.579353        NaN
# Fuel_Type_CNG          NaN        NaN       NaN       NaN        NaN
# Fuel_Type_Diesel       NaN        NaN       NaN       NaN        NaN
# Fuel_Type_Petrol       NaN        NaN       NaN       NaN        NaN
#
# ...

# %%
# 2.Building with Correlation Features

# %%
x_train_model1=x_train.drop(columns='Doors')
x_test_model2=x_test.drop(columns='Doors')
x_train_model1,x_test_model2
# Out:
# (      Age_08_04      KM   HP  Automatic    cc  Cylinders  Gears  Weight  \
#  1192         70   89983  110          0  1600          4      5    1055
#  641          68  119289  110          0  1600          4      5    1035
#  1408         75   43720  110          0  1600          4      5    1070
#  1350         70   60600   86          0  1300          4      5    1060
#  322          44   36066  110          0  1600          4      5    1040
#  ...         ...     ...  ...        ...   ...        ...    ...     ...
#  852          68   65000  110          0  1600          4      5    1070
#  314          41   37533  110          0  1600          4      5    1075
#  884          62   61254  110          0  1600          4      5    1075
#  647          64  116000   86          0  1300          4      5    1045
#  1334         80   64000  110          0  1600          4      5    1055
#
#        Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
mul_model1=LinearRegression()
k=mul_model1.fit(x_train_model1,y_train)
k
# Out:
# LinearRegression()

# %%
y_pred1=mul_model1.predict(x_test_model2)
y_pred1
# Out:
# array([ 7074.03915737,  8213.47378111,  8352.65783004,  8814.40274884,
#         9576.13968231, 11355.24245351,  6705.05880239,  9669.31935596,
#         9382.26644219, 10517.18726394, 12709.18513052,  8217.43958593,
#        12652.42644063, 15240.43891967, 11204.62254689,  8822.22535586,
#        10930.5208565 , 11105.44028799, 10879.45691022,  9410.61422819,
#         9284.08527548, 12275.5525554 , 11720.99357621,  9747.12067341,
#         9445.04124856,  6886.48758333, 11560.70193708, 10637.98465211,
#        11268.44708246, 10522.81145301,  8476.95106936,  9151.0692706 ,
#        10167.40940568,  7785.31162973,  8152.89116121,  9306.4280139 ,
#         9983.12509213,  9725.5560431 , 12531.00683887,  8410.08198156,
#        15665.87129634,  7912.73787557, 10851.00629156,  8739.39955407,
#        11154.48132239,  9119.83340523,  9104.51203794,  8976.32990492,
#         7824.74370953, 12706.84120762,  9139.57956232, 11134.06374075,
# ...

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.8172051426196518

# %%
# Coefficients
mul_model1.coef_
# Out:
# array([-1.06780498e+02, -1.46352722e-02, -7.65772484e+01,  6.11066753e-13,
#         5.53179621e+00,  0.00000000e+00,  0.00000000e+00,  2.08958961e+01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00])

# %%
mul_model1.intercept_
# Out:
# -5197.250536770129

# %%
# there is 81% Accuracy in testing the data

# %%
# 3.Applying Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_scaler=scaler.fit_transform(x_train)

# %%
x_test_scaler=scaler.transform(x_test)

# %%
model3 = LinearRegression()
model3.fit(x_train_scaler, y_train)
# Out:
# LinearRegression()

# %%
y_pred3=model3.predict(x_test_scaler)

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.8178599254583384

# %%
# There is Accuracy of 81% in testing the data

# %%
# Evaluating The Metrics

# %%
mse1=mean_squared_error(y_test,y_predict_test)   # for !st Model
mse1
# Out:
# 958691.1904428393

# %%
r2_score(y_test,y_predict_test)  # for 1st Model
# Out:
# 0.8178599254583384

# %%
mse2=mean_squared_error(y_test,y_pred1)       # for 2nd model
mse2
# Out:
# 962137.6287990422

# %%
r2_score(y_test,y_pred1)   # for 2nd Model
# Out:
# 0.8172051426196518

# %%
mse3=mean_squared_error(y_test,y_pred3)
mse3                                               # for 3rd Model
# Out:
# 958691.1904428396

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.8178599254583384

# %%
# Coefficients
model3.coef_
# Out:
# array([-1.66891298e+03, -3.90193796e+02, -8.17383427e+02,  5.54223334e-13,
#         7.57087833e+02, -5.18300926e+01,  0.00000000e+00,  0.00000000e+00,
#         5.99089723e+02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00])

# %%
model3.intercept_
# Out:
# 10077.34474616293

# %%
# The model with the lowest MSE and highest R-squared is the best fit.

# %%
# Here for 1st and 3rd model having same mean_squared_error and having same r2_score for three models

# %%
#  Apply Lasso and Ridge methods on the model.

# %%
from sklearn.linear_model import Lasso,Ridge
lasso = Lasso(alpha=0.1)  # we can tune the alpha value
lasso.fit(x_train_scaler, y_train)
y_pred_lasso = lasso.predict(x_test_scaler)
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)
mse_lasso,r2_lasso
# Out:
# (959029.2330350667, 0.8177957013332392)

# %%
# Ridge model
ridge = Ridge(alpha=0.1)  # we can tune the alpha value
ridge.fit(x_train_scaler, y_train)
y_pred_ridge = ridge.predict(x_test_scaler)
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)

mse_ridge,r2_ridge
# Out:
# (959063.759458611, 0.8177891417179838)

# %%
# Interview Questions

# %%
# What is Normalization & Standardization and how is it helpful

# %%
##  Normalization is the process of scaling data to a fixed range, typically between 0 and 1, or -1 and 1. 
# The most common formula used for normalization is:

        #  XNorm=(X-Xmin)/(Xmax-Xmin)

# %%
## Standardization transforms the data to have a mean of 0 and a standard deviation of 1. The formula for standardization is

     # standard deviation= Xstd=(X-meu)/(sigma)

# %%
## What techniques can be used to address multicollinearity in multiple linear regression

# %%
## The techniques are
## 1.Remove one of the correlated variables
## 2.Combine the correlated variables
## 3. Principal Component Analysis (PCA)
## 4,Variation Inflation Factor
## 5. Ridge Regression
## 6. Lasso Regression
